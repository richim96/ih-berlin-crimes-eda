# %% [markdown]
# # Berlin Case Study: Crimes in 2012-2019

# %% [markdown]
# ## The Problem
# The city of Berlin hosts a large population (~3.9 million people) and one of the greatest concentrations of expats in Europe. As more and more people from all over the world move to Berlin — drawn by its economy, vibrant lifestyle, and cultural diversity — the city council needs to take a careful look at crime patterns across the city: understand where and how they are evolving, plan targeted interventions, and advise newcomers on what to be aware of before they arrive.

# %% [markdown]
# ## Questions Overview
# 1. Which districts have become more dangerous over time — and which have quietly improved?
# 2. Is the ratio of violent crime (robbery, assault, injury) to property crime (theft, burglary, damage) shifting across the city?
# 3. Where are the crime "hot spots" that consistently rank in the top 10% across multiple crime categories simultaneously?
# 4. How does the arson-to-fire ratio vary by district, and what might that signal?
# 5. Are drug crimes a leading indicator for other crime types in a location the following year?
# 6. Which sub-locations (Locations) are generating disproportionate crime relative to their district average?
# 7. How did crime evolve around the 2015–2016 refugee crisis period, and did the pattern differ between East and West Berlin districts?
# 8. Is bike theft seasonal or structural — and which districts should get targeted enforcement?
# 9. What is the relationship between graffiti/damage and more serious crimes in the same location over time?
# 10. Which districts show the greatest volatility year-to-year, versus those that are stable?

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Data cleaning

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Database creation

# %%
import sqlalchemy as sa

# %% [markdown]
# ## A Deep Dive

# %% [markdown]
# ### 1. Which districts have become more dangerous over time — and which have quietly improved?
